# %%
import sys
import numpy as np
from maraboupy import Marabou
from maraboupy import MarabouNetworkONNX
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import save_model, load_model
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tf2onnx
import onnx

# %% [markdown]
# # Conversion of model
#
# Conversion of the .h5 model to something that the marabou implementation can test

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(108,)),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(300, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification
])
model.output_names = ["output"]

model.load_weights("300x8_8554.h5")

# %%
spec = (tf.TensorSpec((None, 108), tf.float32, name="input"),)

# Convert the Keras model to ONNX
output_path = "model_8x300.onnx"
model_proto, _ = tf2onnx.convert.from_keras(model, input_signature=spec, output_path=output_path)

print(f"Model saved to {output_path}")
# Out:
# I0000 00:00:1741692335.060909 29191590 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# I0000 00:00:1741692335.061009 29191590 single_machine.cc:361] Starting new session
# I0000 00:00:1741692335.150721 29191590 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# I0000 00:00:1741692335.150789 29191590 single_machine.cc:361] Starting new session
# rewriter <function rewrite_constant_fold at 0x176c0b9a0>: exception `np.cast` was removed in the NumPy 2.0 release. Use `np.asarray(arr, dtype=dtype)` instead.
# Model saved to model_8x300.onnx

# %% [markdown]
# # Fairness
#
# We wish to see whether the classification of a network changes when you swap the certain indices.
#
# We will be checking for gender, race, and country of origin

# %%
import time
from maraboupy import Marabou

# Define the index which you want to swap around
index = 13

# Classification threshold (for sigmoid output)
threshold = 0.5
epsilon = 1e-3  # small tolerance

def setup_networks(model_path):
    """
    Load two copies of the network and set up input equality constraints,
    except for the race input, which we enforce to be swapped.
    Returns the two network objects.
    """
    net1 = Marabou.read_onnx(model_path)
    net2 = Marabou.read_onnx(model_path)

    # Retrieve the input variable lists (assuming one input layer)
    inputs1 = net1.inputVars[0][0].tolist()
    inputs2 = net2.inputVars[0][0].tolist()
    
    # For all inputs except race, enforce equality: input1[i] == input2[i]
    for i in range(len(inputs1)):
        if i != index:
            net1.addEquality([inputs1[i], inputs2[i]], [1, -1], 0)
            
    # For the race input, enforce a swap.
    net1.addEquality([inputs1[index], inputs2[index]], [1, 1], 1)
    
    return net1, net2

def check_case(case, model_path):
    """
    Check one of the fairness violation cases.
    case == 1: net1 output >= threshold and net2 output < threshold
    case == 2: net1 output < threshold and net2 output >= threshold
    """
    start_time = time.time()
    
    # Setup networks and constraints common to both
    net1, _ = setup_networks(model_path)
    
    # Retrieve the output variable
    output1 = int(net1.outputVars[0][0])
    
    if case == 1:
        net1.setLowerBound(output1, threshold)
        net1.setUpperBound(output1, threshold - epsilon)
    elif case == 2:
        net1.setUpperBound(output1, threshold - epsilon)
        net1.setLowerBound(output1, threshold)
    else:
        raise ValueError("Case must be 1 or 2.")
    
    exitCode, vals, stats = net1.solve()
    elapsed_time = time.time() - start_time
    
    return exitCode, vals, elapsed_time

model_paths = [
    "model_4x100.onnx", "model_4x200.onnx", "model_4x300.onnx",
    "model_6x100.onnx", "model_6x200.onnx", "model_6x300.onnx",
    "model_8x100.onnx", "model_8x200.onnx", "model_8x300.onnx"
]

# Check Fairness for each model
for model_path in model_paths:
    exitCode1, vals1, time1 = check_case(1, model_path)
    print("Model Path =", model_path)
    print("Time Taken =", round(time1, 4), "seconds")
    
    if exitCode1 == "sat":
        print("Fairness violation found (Case 1): Swapping this index causes classification to change.")
        print("Counterexample:", vals1)
    else:
        exitCode2, vals2, time2 = check_case(2, model_path)
        print("Time Taken (Case 2) =", round(time2, 4), "seconds")
        
        if exitCode2 == "sat":
            print("Fairness violation found (Case 2): Swapping this index causes classification to change.")
            print("Counterexample:", vals2)
        else:
            print("Fairness property holds: Swapping this index does not change the binary classification.")
# Out:
# /var/folders/6k/n28kjgy90gz400d7b72bp_sw0000gn/T/ipykernel_84340/299286863.py:46: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   output1 = int(net1.outputVars[0][0])
# unsatEngine::processInputQuery: Input query (before preprocessing): 509 equations, 910 variables
#
# Model Path = model_4x100.onnx
# Time Taken = 0.8857 seconds
# Engine::processInputQuery: Input query (before preprocessing): 509 equations, 910 variables
# unsat
# Time Taken (Case 2) = 0.4468 seconds
# Fairness property holds: Swapping this index does not change the binary classification.
# Engine::processInputQuery: Input query (before preprocessing): 909 equations, 1710 variables
# unsat
# Model Path = model_4x200.onnx
# Time Taken = 1.6386 seconds
# Engine::processInputQuery: Input query (before preprocessing): 909 equations, 1710 variables
# unsat
# Time Taken (Case 2) = 1.6498 seconds
# Fairness property holds: Swapping this index does not change the binary classification.
# Engine::processInputQuery: Input query (before preprocessing): 1309 equations, 2510 variables
# unsat
# Model Path = model_4x300.onnx
# Time Taken = 3.6778 seconds
# Engine::processInputQuery: Input query (before preprocessing): 1309 equations, 2510 variables
# unsat
# Time Taken (Case 2) = 3.2577 seconds
# Fairness property holds: Swapping this index does not change the binary classification.
# Engine::processInputQuery: Input query (before preprocessing): 709 equations, 1310 variables
# unsat
# Model Path = model_6x100.onnx
# Time Taken = 0.9679 seconds
# Engine::processInputQuery: Input query (before preprocessing): 709 equations, 1310 variables
# unsat
# Time Taken (Case 2) = 0.685 seconds
# Fairness property holds: Swapping this index does not change the binary classification.
# Engine::processInputQuery: Input query (before preprocessing): 1309 equations, 2510 variables
# unsat
# Model Path = model_6x200.onnx
# Time Taken = 2.3674 seconds
# Engine::processInputQuery: Input query (before preprocessing): 1309 equations, 2510 variables
# unsat
# Time Taken (Case 2) = 2.6872 seconds
# Fairness property holds: Swapping this index does not change the binary classification.
# Engine::processInputQuery: Input query (before preprocessing): 1909 equations, 3710 variables
# unsat
# Model Path = model_6x300.onnx
# Time Taken = 6.2028 seconds
# Engine::processInputQuery: Input query (before preprocessing): 1909 equations, 3710 variables
# unsat
# Time Taken (Case 2) = 6.4065 seconds
# Fairness property holds: Swapping this index does not change the binary classification.
# Engine::processInputQuery: Input query (before preprocessing): 909 equations, 1710 variables
# unsat
# Model Path = model_8x100.onnx
# Time Taken = 0.9025 seconds
# Engine::processInputQuery: Input query (before preprocessing): 909 equations, 1710 variables
# unsat
# Time Taken (Case 2) = 0.932 seconds
# Fairness property holds: Swapping this index does not change the binary classification.
# Engine::processInputQuery: Input query (before preprocessing): 1709 equations, 3310 variables
# unsat
# Model Path = model_8x200.onnx
# Time Taken = 4.7075 seconds
# Engine::processInputQuery: Input query (before preprocessing): 1709 equations, 3310 variables
# unsat
# Time Taken (Case 2) = 4.1168 seconds
# Fairness property holds: Swapping this index does not change the binary classification.
# unsatEngine::processInputQuery: Input query (before preprocessing): 2509 equations, 4910 variables
#
# Model Path = model_8x300.onnx
# Time Taken = 8.0471 seconds
# Engine::processInputQuery: Input query (before preprocessing): 2509 equations, 4910 variables
# unsat
# Time Taken (Case 2) = 9.8563 seconds
# Fairness property holds: Swapping this index does not change the binary classification.

# %% [markdown]
# # Average vector
#
# We wish to find what the average vector is for the <50k and the >=50k classes

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder

# Define column names and file paths
column_names = [
    "age", "workclass", "fnlwgt", "education", "education.num",
    "marital.status", "occupation", "relationship", "race", "sex",
    "capital.gain", "capital.loss", "hours.per.week",
    "native.country", "income"
]

train_path = "/Users/smayanagarwal/Downloads/adult/adult.data" 

# Load the training data with skipinitialspace to clean up extra spaces
df_train = pd.read_csv(
    train_path, 
    header=None, 
    names=column_names,
    na_values="?",
    skipinitialspace=True
)

# Filter the dataset for categorical samples
male_df = df_train[df_train["income"] == "<=50K"]

# Define which columns are numerical and which are categorical (EXCLUDING income)
numerical_cols = ["age", "fnlwgt", "education.num", "capital.gain", "capital.loss", "hours.per.week"]
categorical_cols = ["workclass", "education", "marital.status", "occupation", 
                    "relationship", "race", "sex", "native.country"]  # Removed "income"

# Compute the average (mean) for numerical columns.
male_num_avg = male_df[numerical_cols].mean().values  # e.g., shape (6,)

# One-hot encode the categorical columns (fit on full dataset to ensure all categories exist)
encoder = OneHotEncoder(sparse_output=False, handle_unknown="ignore")
encoder.fit(df_train[categorical_cols])  # Fit on full dataset
male_cat_encoded = encoder.transform(male_df[categorical_cols])  # Transform only on male data

# Compute the average over the one-hot encoded rows.
male_cat_avg = np.mean(male_cat_encoded, axis=0)  # shape (num_encoded_features,)

# Debugging: Check shapes
# print("Numerical Features Shape:", male_num_avg.shape)
# print("Categorical Features Shape:", male_cat_avg.shape)
# print("Total Expected Shape:", male_num_avg.shape[0] + male_cat_avg.shape[0])

# Concatenate the numeric and one-hot averaged categorical parts.
x_avg = np.concatenate([male_num_avg, male_cat_avg])

print("Final Computed Average Vector Shape:", x_avg.shape)  # Should be (108,)
print (x_avg)
np.save("y_avg.npy", x_avg)
# Out:
# Final Computed Average Vector Shape: (108,)
# [3.67837379e+01 1.90340865e+05 9.59506472e+00 1.48752468e+02
#  5.31429207e+01 3.88402104e+01 2.38268608e-02 5.97087379e-02
#  2.83171521e-04 7.17354369e-01 1.99838188e-02 7.35032362e-02
#  3.82281553e-02 5.66343042e-04 6.65453074e-02 3.52346278e-02
#  4.51051780e-02 1.61812298e-02 6.55339806e-03 1.28236246e-02
#  2.45145631e-02 1.97006472e-02 3.24433657e-02 4.13025890e-02
#  1.26779935e-01 4.32847896e-03 3.57038835e-01 3.09061489e-02
#  2.06310680e-03 6.18932039e-03 2.38834951e-01 1.61003236e-01
#  5.25889968e-04 3.35113269e-01 1.55339806e-02 4.12297735e-01
#  3.87944984e-02 3.67313916e-02 1.31998382e-01 3.23624595e-04
#  1.28236246e-01 8.48705502e-02 3.55582524e-02 5.19417476e-02
#  7.08737864e-02 1.27750809e-01 5.98705502e-03 9.22734628e-02
#  1.77184466e-02 1.07888350e-01 2.60922330e-02 5.16585761e-02
#  6.68284790e-02 2.94296117e-01 3.01334951e-01 3.81877023e-02
#  2.02305825e-01 1.30582524e-01 3.32928803e-02 1.11245955e-02
#  3.08656958e-02 1.10720065e-01 9.95145631e-03 8.37338188e-01
#  3.88025890e-01 6.11974110e-01 4.85436893e-04 3.31715210e-03
#  2.22491909e-03 2.30582524e-03 2.83171521e-03 2.75080906e-03
#  9.70873786e-04 3.92394822e-03 2.42718447e-03 6.87702265e-04
#  3.76213592e-03 8.49514563e-04 2.46763754e-03 1.61812298e-03
#  4.04530744e-05 4.85436893e-04 5.66343042e-04 4.04530744e-04
#  2.42718447e-03 1.01132686e-03 7.68608414e-04 1.94174757e-03
#  2.87216828e-03 1.53721683e-03 6.47249191e-04 2.46763754e-02
#  1.29449838e-03 5.66343042e-04 1.17313916e-03 5.54207120e-03
#  1.94174757e-03 1.33495146e-03 4.12621359e-03 3.64077670e-04
#  2.58899676e-03 1.25404531e-03 6.06796117e-04 6.87702265e-04
#  8.89927184e-01 2.50809061e-03 4.04530744e-04 1.76779935e-02]

# %% [markdown]
# # Robustness
#
# We wish to see how robust the network is to perturbations around the average vector. Ideally for an epsilon ball of say 1% around the average, the classification does not change

# %%
import numpy as np
from maraboupy import Marabou
from contextlib import redirect_stdout
import os


def epsilon_ball(model_path):
    net = Marabou.read_onnx(model_path)

# Load x_avg from file (or compute it in your current kernel)
    x_avg = np.load("x_avg.npy")

    # Access the input variable list; adjust indexing based on your network structure.
    # Here we assume net.inputVars[0][0] is an array of input variable IDs.
    inputs = net.inputVars[0][0].tolist()

    # Set epsilon as 5% of the average for each input dimension.
    for i, var in enumerate(inputs):
        # Compute epsilon_i as 5% of the absolute value of x_avg[i]
        epsilon_i = 0.01 * abs(x_avg[i])
        # Optionally, set a minimum epsilon (e.g., 0.01) if needed:
        # epsilon_i = max(0.05 * abs(x_avg[i]), 0.01)
        net.setLowerBound(var, x_avg[i] - epsilon_i)
        net.setUpperBound(var, x_avg[i] + epsilon_i)

    # Now you have set your input constraints to be within 5% of x_avg.
    with open(os.devnull, "w") as fnull:
        with redirect_stdout(fnull):
            exitCode, vals, stats = net.solve()
    print ("MODEL PATH:", model_path)
    if exitCode == "unsat":
        print("The network is robust in the 1% ε-ball around the average input.")
    else:
        print("Found a counterexample within the 1% ε-ball that changes the classification.")
        print("Counterexample:", vals)

# %%
model_paths = ["model_4x100.onnx","model_4x200.onnx","model_4x300.onnx","model_6x100.onnx","model_6x200.onnx","model_6x300.onnx","model_8x100.onnx","model_8x200.onnx","model_8x300.onnx"]
for model_path in model_paths:
    epsilon_ball(model_path)
# Out:
# WARNING:tensorflow:From /Users/smayanagarwal/Desktop/Smayan TAI A2/.venv/lib/python3.10/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Engine::processInputQuery: Input query (before preprocessing): 401 equations, 910 variables
# MODEL PATH: model_4x100.onnx
# Found a counterexample within the 1% ε-ball that changes the classification.
# Counterexample: {0: 43.80734217574289, 1: 186124.95, 2: 11.727773243208775, 3: 4046.2038808825405, 4: 193.05151511286826, 5: 45.92775666369085, 6: 0.04684223951026655, 7: 0.07947583216426476, 8: 0.0, 9: 0.6266254304297921, 10: 0.07853335033796709, 11: 0.09325851294477745, 12: 0.04546996556561663, 13: 0.0, 14: 0.02411554648641755, 15: 0.0078280831526591, 16: 0.007575564341282999, 17: 0.004166560387705649, 18: 0.0007728606045147303, 19: 0.0020201504910088, 20: 0.005152404030098202, 21: 0.00340900395357735, 22: 0.03345874250733325, 23: 0.045579645453386046, 24: 0.2804221400331591, 25: 0.03941589083025124, 26: 0.21148450452748374, 27: 0.12352888662160438, 28: 0.0, 29: 0.05448667261828848, 30: 0.17865960974365513, 31: 0.05845810483356715, 32: 0.0012881010075245505, 33: 0.8619971942354292, 34: 0.0042928197933937, 35: 0.06199336819283255, 36: 0.008333120775411299, 37: 0.01073204948348425, 38: 0.06401351868384135, 39: 0.00012625940568805, 40: 0.11729498788419845, 41: 0.25349827828083155, 42: 0.014519831654125749, 43: 0.0108583088891723, 44: 0.032202525188113756, 45: 0.01729753857926285, 46: 0.00012625940568805, 47: 0.23471623517408494, 48: 0.02664073460017855, 49: 0.1266203290396633, 50: 0.03645325851294478, 51: 0.041219232240785615, 52: 0.024602729243718913, 53: 0.762298176253029, 54: 0.10807805126897078, 55: 0.00467159801045785, 56: 0.00845938018109935, 57: 0.0275245504399949, 58: 0.09596352506057901, 59: 0.0045453386047698, 60: 0.035551587807677594, 61: 0.04886239000127535, 62: 0.003220252518811376, 63:
# 	x11: [  0.0914,   0.0933]
# 	x12: [  0.0446,   0.0455]
# 	x13: [  0.0000,   0.0000] [FIXED]
# 	x14: [  0.0241,   0.0246]
# 	x15: [  0.0078,   0.0080]
# 	x16: [  0.0076,   0.0077]
# 	x17: [  0.0042,   0.0043]
# 	x18: [  0.0008,   0.0008]
# 	x19: [  0.0020,   0.0021]
# 	x20: [  0.0051,   0.0052]
# 	x21: [  0.0034,   0.0035]
# 	x22: [  0.0335,   0.0341]
# 	x23: [  0.0456,   0.0465]
# 	x24: [  0.2804,   0.2861]
# 	x25: [  0.0386,   0.0394]
# 	x26: [  0.2115,   0.2158]
# 	x27: [  0.1211,   0.1235]
# 	x28: [  0.0000,   0.0000] [FIXED]
# 	x29: [  0.0534,   0.0545]
# 	x30: [  0.1751,   0.1787]
# 	x31: [  0.0585,   0.0596]
# 	x32: [  0.0013,   0.0013]
# 	x33: [  0.8449,   0.8620]
# 	x34: [  0.0043,   0.0044]
# 	x35: [  0.0620,   0.0632]
# 	x36: [  0.0083,   0.0085]
# 	x37: [  0.0107,   0.0109]
# 	x38: [  0.0640,   0.0653]
# 	x39: [  0.0001,   0.0001] [FIXED]
# 	x40: [  0.1173,   0.1197]
# 	x41: [  0.2485,   0.2535]
# 	x42: [  0.0145,   0.0148]
# 	x43: [  0.0109,   0.0111]
# 	x44: [  0.0316,   0.0322]
# 	x45: [  0.0173,   0.0176]
# 	x46: [  0.0001,   0.0001] [FIXED]
# 	x47: [  0.2347,   0.2395]
# 	x48: [  0.0266,   0.0272]
# 	x49: [  0.1241,   0.1266]
# 	x50: [  0.0357,   0.0365]
# 	x51: [  0.0404,   0.0412]
# 	x52: [  0.0241,   0.0246]
# 	x53: [  0.7472,   0.7623]
# 	x54: [  0.1081,   0.1103]
# 	x55: [  0.0047,   0.0048]
# 	x56: [  0.0085,   0.0086]
# 	x57: [  0.0275,   0.0281]
# 	x58: [  0.0941,   0.0960]
# 	x59: [  0.0045,   0.0046]
# 	x60: [  0.0348,   0.0356]
# 	x61: [  0.0489,   0.0498]
# 	x62: [  0.0032,   0.0032]
# 	x63: [  0.8986,   0.9167]
# 	x64: [  0.1489,   0.1519]
# 	x65: [  0.8411,   0.8581]
# 	x66: [  0.0009,   0.0009]
# 	x67: [  0.0049,   0.0050]
# 	x68: [  0.0025,   0.0026]
# 	x69: [  0.0003,   0.0003] [FIXED]
# 	x70: [  0.0032,   0.0032]
# 	x71: [  0.0003,   0.0003] [FIXED]
# 	x72: [  0.0005,   0.0005]
# 	x73: [  0.0011,   0.0012]
# 	x74: [  0.0038,   0.0039]
# 	x75: [  0.0015,   0.0015]
# 	x76: [  0.0056,   0.0057]
# 	x77: [  0.0010,   0.0010]
# 	x78: [  0.0004,   0.0004] [FIXED]
# 	x79: [  0.0005,   0.0005]
# 	x80: [  0.0000,   0.0000] [FIXED]
# 	x81: [  0.0001,   0.0001] [FIXED]
# 	x82: [  0.0008,   0.0008]
# 	x83: [  0.0004,   0.0004] [FIXED]
# 	x84: [  0.0051,   0.0052]
# 	x85: [  0.0023,   0.0023]
# 	x86: [  0.0006,   0.0006]
# 	x87: [  0.0032,   0.0032]
# 	x88: [  0.0013,   0.0013]
# 	x89: [  0.0030,   0.0031]
# 	x90: [  0.0003,   0.0003] [FIXED]
# 	x91: [  0.0042,   0.0043]
# 	x92: [  0.0003,   0.0003] [FIXED]
# 	x93: [  0.0000,   0.0000] [FIXED]
# 	x94: [  0.0003,   0.0003] [FIXED]
# 	x95: [  0.0077,   0.0079]
# 	x96: [  0.0015,   0.0015]
# 	x97: [  0.0005,   0.0005]
# 	x98: [  0.0015,   0.0015]
# 	x99: [  0.0004,   0.0004] [FIXED]
# 	x100: [  0.0020,   0.0021]
# 	x101: [  0.0025,   0.0026]
# 	x102: [  0.0004,   0.0004] [FIXED]
# 	x103: [  0.0003,   0.0003] [FIXED]
# 	x104: [  0.9054,   0.9237]
# 	x105: [  0.0006,   0.0006]
# 	x106: [  0.0008,   0.0008]
# 	x107: [  0.0184,   0.0188]
#
# Branching heuristics set to PseudoImpact
#
# Engine::solve: Initial statistics
#
# 19:41:55 Statistics update:
# 	--- Time Statistics ---
# 	Total time elapsed: 270 milli (00:00:00)
# 		Main loop: 0 milli (00:00:00)
# 		Preprocessing time: 248 milli (00:00:00)
# 		Unknown: 22 milli (00:00:00)
# 	Breakdown for main loop:
# 		[0.00%] Simplex steps: 0 milli
# 		[0.00%] Explicit-basis bound tightening: 0 milli
# 		[0.00%] Constraint-matrix bound tightening: 0 milli
# 		[0.00%] Degradation checking: 0 milli
# 		[0.00%] Precision restoration: 0 milli
# 		[0.00%] Statistics handling: 0 milli
# 		[0.00%] Constraint-fixing steps: 0 milli
# 		[0.00%] Valid case splits: 0 milli. Average per split: 0.00 milli
# 		[0.00%] Applying stored bound-tightening: 0 milli
# 		[0.00%] SMT core: 0 milli
# 		[0.00%] Symbolic Bound Tightening: 109 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] Unaccounted for: 0 milli
# 	--- Preprocessor Statistics ---
# 	Number of preprocessor bound-tightening loop iterations: 6
# 	Number of eliminated variables: 323
# 	Number of constraints removed due to variable elimination: 305
# 	Number of equations removed due to variable elimination: 0
# 	--- Engine Statistics ---
# 	Number of main loop iterations: 1
# 		0 iterations were simplex steps. Total time: 0 milli. Average: 0.00 milli.
# 		0 iterations were constraint-fixing steps. Total time: 0 milli. Average: 0.00 milli
# 	Number of active piecewise-linear constraints: 95 / 95
# 		Constraints disabled by valid splits: 0. By SMT-originated splits: 0
# 	Last reported degradation: 0.0000000000. Max degradation so far: 0.0000000000. Restorations so far: 0
# 	Number of simplex pivots we attempted to skip because of instability: 0.
# 	Unstable pivots performed anyway: 0
# 	--- Tableau Statistics ---
# 	Total number of pivots performed: 0
# 		Real pivots: 0. Degenerate: 0 (0.00%)
# 		Degenerate pivots by request (e.g., to fix a PL constraint): 0 (0.00%)
# 		Average time per pivot: 0.00 milli
# 	Total number of fake pivots performed: 0
# 	Total number of rows added: 0. Number of merged columns: 0
# 	Current tableau dimensions: M = 801, N = 1806
# 	--- SMT Core Statistics ---
# 	Total depth is 0. Total visited states: 1. Number of splits: 0. Number of pops: 0
# 	Max stack depth: 0
# 	--- Bound Tightening Statistics ---
# 	Number of tightened bounds: 0.
# 		Number of rows examined by row tightener: 0. Consequent tightenings: 0
# 		Number of explicit basis matrices examined by row tightener: 0. Consequent tightenings: 0
# 		Number of bound tightening rounds on the entire constraint matrix: 0. Consequent tightenings: 0
# 		Number of bound notifications sent to PL constraints: 570. Tightenings proposed: 0
# 	--- Basis Factorization statistics ---
# 	Number of basis refactorizations: 2
# 	--- Projected Steepest Edge Statistics ---
# 	Number of iterations: 0.
# 	Number of resets to reference space: 1. Avg. iterations per reset: 0
# 	--- SBT ---
# 	Number of tightened bounds: 883
# 	--- SoI-based local search ---
# 	Number of proposed phase pattern update: 0. Number of accepted update: 0 [0.00%]
# 	Total time (% of local search time) updating SoI phase pattern : 0 milli [0.00%]
# 	Total time obtaining current assignment: 0 milli [0.00%]
# 	Total time getting SoI phase pattern : 0 milli [0.00%]
# 	--- Context dependent statistics ---
# 	Number of pushes / pops: 0 / 0
# 		[0.00%] Pre-Push hook: 0 milli
# 		[0.00%] Push : 0 milli
# 		[0.00%] Post-Pop hook: 0 milli
# 		[0.00%] Pop : 0 milli
# 		[0.00%] Total context-switching time: 0 milli
# 	--- Proof Certificate ---
# 	Number of certified leaves: 0
# 	Number of leaves to delegate: 0
#
# ---
# Before declaring sat, recomputing...
#
# Engine::solve: sat assignment found
#
# 19:41:56 Statistics update:
# 	--- Time Statistics ---
# 	Total time elapsed: 987 milli (00:00:00)
# 		Main loop: 715 milli (00:00:00)
# 		Preprocessing time: 248 milli (00:00:00)
# 		Unknown: 23 milli (00:00:00)
# 	Breakdown for main loop:
# 		[25.94%] Simplex steps: 185 milli
# 		[44.47%] Explicit-basis bound tightening: 318 milli
# 		[0.00%] Constraint-matrix bound tightening: 0 milli
# 		[0.71%] Degradation checking: 5 milli
# 		[0.00%] Precision restoration: 0 milli
# 		[0.04%] Statistics handling: 0 milli
# 		[0.00%] Constraint-fixing steps: 0 milli
# 		[0.09%] Valid case splits: 0 milli. Average per split: 0.00 milli
# 		[0.00%] Applying stored bound-tightening: 0 milli
# 		[0.00%] SMT core: 0 milli
# 		[43.68%] Symbolic Bound Tightening: 312 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[2578276606879615.00%] Unaccounted for: 0 milli
# 	--- Preprocessor Statistics ---
# 	Number of preprocessor bound-tightening loop iterations: 6
# 	Number of eliminated variables: 323
# 	Number of constraints removed due to variable elimination: 305
# 	Number of equations removed due to variable elimination: 0
# 	--- Engine Statistics ---
# 	Number of main loop iterations: 424
# 		421 iterations were simplex steps. Total time: 185 milli. Average: 0.44 milli.
# 		0 iterations were constraint-fixing steps. Total time: 0 milli. Average: 0.00 milli
# 	Number of active piecewise-linear constraints: 1 / 95
# 		Constraints disabled by valid splits: 94. By SMT-originated splits: 0
# 	Last reported degradation: 0.0000000040. Max degradation so far: 0.0000000040. Restorations so far: 0
# 	Number of simplex pivots we attempted to skip because of instability: 0.
# 	Unstable pivots performed anyway: 0
# 	--- Tableau Statistics ---
# 	Total number of pivots performed: 258
# 		Real pivots: 251. Degenerate: 7 (2.71%)
# 		Degenerate pivots by request (e.g., to fix a PL constraint): 0 (0.00%)
# 		Average time per pivot: 0.26 milli
# 	Total number of fake pivots performed: 163
# 	Total number of rows added: 0. Number of merged columns: 0
# 	Current tableau dimensions: M = 801, N = 1806
# 	--- SMT Core Statistics ---
# 	Total depth is 0. Total visited states: 1. Number of splits: 0. Number of pops: 0
# 	Max stack depth: 0
# 	--- Bound Tightening Statistics ---
# 	Number of tightened bounds: 0.
# 		Number of rows examined by row tightener: 258. Consequent tightenings: 0
# 		Number of explicit basis matrices examined by row tightener: 4. Consequent tightenings: 291
# 		Number of bound tightening rounds on the entire constraint matrix: 0. Consequent tightenings: 0
# 		Number of bound notifications sent to PL constraints: 1142. Tightenings proposed: 0
# 	--- Basis Factorization statistics ---
# 	Number of basis refactorizations: 4
# 	--- Projected Steepest Edge Statistics ---
# 	Number of iterations: 421.
# 	Number of resets to reference space: 1. Avg. iterations per reset: 421
# 	--- SBT ---
# 	Number of tightened bounds: 883
# 	--- SoI-based local search ---
# 	Number of proposed phase pattern update: 0. Number of accepted update: 0 [0.00%]
# 	Total time (% of local search time) updating SoI phase pattern : 0 milli [0.00%]
# 	Total time obtaining current assignment: 0 milli [0.00%]
# 	Total time getting SoI phase pattern : 0 milli [0.00%]
# 	--- Context dependent statistics ---
# 	Number of pushes / pops: 0 / 0
# 		[0.00%] Pre-Push hook: 0 milli
# 		[0.00%] Push : 0 milli
# 		[0.00%] Post-Pop hook: 0 milli
# 		[0.00%] Pop : 0 milli
# 		[0.00%] Total context-switching time: 0 milli
# 	--- Proof Certificate ---
# 	Number of certified leaves: 0
# 	Number of leaves to delegate: 0
# Engine::processInputQuery: Input query (before preprocessing): 801 equations, 1710 variables
# Engine::processInputQuery: Input query (after preprocessing): 1601 equations, 1927 variables
#
# Input bounds:
# 	x0: [ 43.8073,  44.6923]
# 	x1: [186124.9500, 189885.0500]
# 	x2: [ 11.4955,  11.7278]
# 	x3: [3966.0810, 4046.2039]
# 	x4: [193.0515, 196.9515]
# 	x5: [ 45.0183,  45.9278]
# 	x6: [  0.0468,   0.0478]
# 	x7: [  0.0779,   0.0795]
# 	x8: [  0.0000,   0.0000] [FIXED]
# 	x9: [  0.6266,   0.6393]
# 	x10: [  0.0785,   0.0801]
# 	x11: [  0.0914,   0.0933]
# 	x12: [  0.0446,   0.0455]
# 	x13: [  0.0000,   0.0000] [FIXED]
# 	x14: [  0.0241,   0.0246]
# 	x15: [  0.0078,   0.0080]
# 	x16: [  0.0076,   0.0077]
# 	x17: [  0.0042,   0.0043]
# 	x18: [  0.0008,   0.0008]
# 	x66: [  0.0009,   0.0009]
# 	x67: [  0.0049,   0.0050]
# 	x68: [  0.0025,   0.0026]
# 	x69: [  0.0003,   0.0003] [FIXED]
# 	x70: [  0.0032,   0.0032]
# 	x71: [  0.0003,   0.0003] [FIXED]
# 	x72: [  0.0005,   0.0005]
# 	x73: [  0.0011,   0.0012]
# 	x74: [  0.0038,   0.0039]
# 	x75: [  0.0015,   0.0015]
# 	x76: [  0.0056,   0.0057]
# 	x77: [  0.0010,   0.0010]
# 	x78: [  0.0004,   0.0004] [FIXED]
# 	x79: [  0.0005,   0.0005]
# 	x80: [  0.0000,   0.0000] [FIXED]
# 	x81: [  0.0001,   0.0001] [FIXED]
# 	x82: [  0.0008,   0.0008]
# 	x83: [  0.0004,   0.0004] [FIXED]
# 	x84: [  0.0051,   0.0052]
# 	x85: [  0.0023,   0.0023]
# 	x86: [  0.0006,   0.0006]
# 	x87: [  0.0032,   0.0032]
# 	x88: [  0.0013,   0.0013]
# 	x89: [  0.0030,   0.0031]
# 	x90: [  0.0003,   0.0003] [FIXED]
# 	x91: [  0.0042,   0.0043]
# 	x92: [  0.0003,   0.0003] [FIXED]
# 	x93: [  0.0000,   0.0000] [FIXED]
# 	x94: [  0.0003,   0.0003] [FIXED]
# 	x95: [  0.0077,   0.0079]
# 	x96: [  0.0015,   0.0015]
# 	x97: [  0.0005,   0.0005]
# 	x98: [  0.0015,   0.0015]
# 	x99: [  0.0004,   0.0004] [FIXED]
# 	x100: [  0.0020,   0.0021]
# 	x101: [  0.0025,   0.0026]
# 	x102: [  0.0004,   0.0004] [FIXED]
# 	x103: [  0.0003,   0.0003] [FIXED]
# 	x104: [  0.9054,   0.9237]
# 	x105: [  0.0006,   0.0006]
# 	x106: [  0.0008,   0.0008]
# 	x107: [  0.0184,   0.0188]
#
# Branching heuristics set to PseudoImpact
#
# Engine::solve: Initial statistics
#
# 19:41:57 Statistics update:
# 	--- Time Statistics ---
# 	Total time elapsed: 842 milli (00:00:00)
# 		Main loop: 0 milli (00:00:00)
# 		Preprocessing time: 734 milli (00:00:00)
# 		Unknown: 107 milli (00:00:00)
# 	Breakdown for main loop:
# 		[0.00%] Simplex steps: 0 milli
# 		[0.00%] Explicit-basis bound tightening: 0 milli
# 		[0.00%] Constraint-matrix bound tightening: 0 milli
# 		[0.00%] Degradation checking: 0 milli
# 		[0.00%] Precision restoration: 0 milli
# 		[0.00%] Statistics handling: 0 milli
# 		[0.00%] Constraint-fixing steps: 0 milli
# 		[0.00%] Valid case splits: 0 milli. Average per split: 0.00 milli
# 		[0.00%] Applying stored bound-tightening: 0 milli
# 		[0.00%] SMT core: 0 milli
# 		[0.00%] Symbolic Bound Tightening: 133 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] Unaccounted for: 0 milli
# 	--- Preprocessor Statistics ---
# 	Number of preprocessor bound-tightening loop iterations: 7
# 	Number of eliminated variables: 601
# 	Number of constraints removed due to variable elimination: 583
# 	Number of equations removed due to variable elimination: 0
# 	--- Engine Statistics ---
# 	Number of main loop iterations: 1
# 		0 iterations were simplex steps. Total time: 0 milli. Average: 0.00 milli.
# 		0 iterations were constraint-fixing steps. Total time: 0 milli. Average: 0.00 milli
# 	Number of active piecewise-linear constraints: 217 / 217
# 		Constraints disabled by valid splits: 0. By SMT-originated splits: 0
# 	Last reported degradation: 0.0000000000. Max degradation so far: 0.0000000000. Restorations so far: 0
# 	Number of simplex pivots we attempted to skip because of instability: 0.
# 	Unstable pivots performed anyway: 0
# 	--- Tableau Statistics ---
# 	Total number of pivots performed: 0
# 		Real pivots: 0. Degenerate: 0 (0.00%)
# 		Degenerate pivots by request (e.g., to fix a PL constraint): 0 (0.00%)
# 		Average time per pivot: 0.00 milli
# 	Total number of fake pivots performed: 0
# 	Total number of rows added: 0. Number of merged columns: 0
# 	Current tableau dimensions: M = 1601, N = 3528
# 	--- SMT Core Statistics ---
# 	Total depth is 0. Total visited states: 1. Number of splits: 0. Number of pops: 0
# 	Max stack depth: 0
# 	--- Bound Tightening Statistics ---
# 	Number of tightened bounds: 0.
# 		Number of rows examined by row tightener: 0. Consequent tightenings: 0
# 		Number of explicit basis matrices examined by row tightener: 0. Consequent tightenings: 0
# 		Number of bound tightening rounds on the entire constraint matrix: 0. Consequent tightenings: 0
# 		Number of bound notifications sent to PL constraints: 1302. Tightenings proposed: 0
# 	--- Basis Factorization statistics ---
# 	Number of basis refactorizations: 2
# 	--- Projected Steepest Edge Statistics ---
# 	Number of iterations: 0.
# 	Number of resets to reference space: 1. Avg. iterations per reset: 0
# 	--- SBT ---
# 	Number of tightened bounds: 1637
# 	--- SoI-based local search ---
# 	Number of proposed phase pattern update: 0. Number of accepted update: 0 [0.00%]
# 	Total time (% of local search time) updating SoI phase pattern : 0 milli [0.00%]
# 	Total time obtaining current assignment: 0 milli [0.00%]
# 	Total time getting SoI phase pattern : 0 milli [0.00%]
# 	--- Context dependent statistics ---
# 	Number of pushes / pops: 0 / 0
# 		[0.00%] Pre-Push hook: 0 milli
# 		[0.00%] Push : 0 milli
# 		[0.00%] Post-Pop hook: 0 milli
# 		[0.00%] Pop : 0 milli
# 		[0.00%] Total context-switching time: 0 milli
# 	--- Proof Certificate ---
# 	Number of certified leaves: 0
# 	Number of leaves to delegate: 0
#
# ---
# Before declaring sat, recomputing...
#
# Engine::solve: sat assignment found
#
# 19:42:01 Statistics update:
# 	--- Time Statistics ---
# 	Total time elapsed: 4152 milli (00:00:04)
# 		Main loop: 3309 milli (00:00:03)
# 		Preprocessing time: 734 milli (00:00:00)
# 		Unknown: 108 milli (00:00:00)
# 	Breakdown for main loop:
# 		[27.24%] Simplex steps: 901 milli
# 		[62.85%] Explicit-basis bound tightening: 2079 milli
# 		[0.00%] Constraint-matrix bound tightening: 0 milli
# 		[0.66%] Degradation checking: 21 milli
# 		[0.00%] Precision restoration: 0 milli
# 		[0.03%] Statistics handling: 1 milli
# 		[0.00%] Constraint-fixing steps: 0 milli
# 		[0.03%] Valid case splits: 0 milli. Average per split: 0.00 milli
# 		[0.00%] Applying stored bound-tightening: 0 milli
# 		[0.00%] SMT core: 0 milli
# 		[13.06%] Symbolic Bound Tightening: 432 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[557377875647123.38%] Unaccounted for: 0 milli
# 	--- Preprocessor Statistics ---
# 	Number of preprocessor bound-tightening loop iterations: 7
# 	Number of eliminated variables: 601
# 	Number of constraints removed due to variable elimination: 583
# 	Number of equations removed due to variable elimination: 0
# 	--- Engine Statistics ---
# 	Number of main loop iterations: 765
# 		762 iterations were simplex steps. Total time: 901 milli. Average: 1.18 milli.
# 		0 iterations were constraint-fixing steps. Total time: 0 milli. Average: 0.00 milli
# 	Number of active piecewise-linear constraints: 1 / 217
# 		Constraints disabled by valid splits: 216. By SMT-originated splits: 0
# 	Last reported degradation: 0.0000000101. Max degradation so far: 0.0000000101. Restorations so far: 0
# 	Number of simplex pivots we attempted to skip because of instability: 0.
# 	Unstable pivots performed anyway: 0
# 	--- Tableau Statistics ---
# 	Total number of pivots performed: 513
# 		Real pivots: 498. Degenerate: 15 (2.92%)
# 		Degenerate pivots by request (e.g., to fix a PL constraint): 0 (0.00%)
# 		Average time per pivot: 0.56 milli
# 	Total number of fake pivots performed: 249
# 	Total number of rows added: 0. Number of merged columns: 0
# 	Current tableau dimensions: M = 1601, N = 3528
# 	--- SMT Core Statistics ---
# 	Total depth is 0. Total visited states: 1. Number of splits: 0. Number of pops: 0
# 	Max stack depth: 0
# 	--- Bound Tightening Statistics ---
# 	Number of tightened bounds: 0.
# 		Number of rows examined by row tightener: 513. Consequent tightenings: 2
# 		Number of explicit basis matrices examined by row tightener: 6. Consequent tightenings: 782
# 		Number of bound tightening rounds on the entire constraint matrix: 0. Consequent tightenings: 0
# 		Number of bound notifications sent to PL constraints: 2651. Tightenings proposed: 0
# 	--- Basis Factorization statistics ---
# 	Number of basis refactorizations: 6
# 	--- Projected Steepest Edge Statistics ---
# 	Number of iterations: 762.
# 	Number of resets to reference space: 1. Avg. iterations per reset: 762
# 	--- SBT ---
# 	Number of tightened bounds: 1637
# 	--- SoI-based local search ---
# 	Number of proposed phase pattern update: 0. Number of accepted update: 0 [0.00%]
# 	Total time (% of local search time) updating SoI phase pattern : 0 milli [0.00%]
# 	Total time obtaining current assignment: 0 milli [0.00%]
# 	Total time getting SoI phase pattern : 0 milli [0.00%]
# 	--- Context dependent statistics ---
# 	Number of pushes / pops: 0 / 0
# 		[0.00%] Pre-Push hook: 0 milli
# 		[0.00%] Push : 0 milli
# 		[0.00%] Post-Pop hook: 0 milli
# 		[0.00%] Pop : 0 milli
# 		[0.00%] Total context-switching time: 0 milli
# 	--- Proof Certificate ---
# 	Number of certified leaves: 0
# 	Number of leaves to delegate: 0
# Engine::processInputQuery: Input query (before preprocessing): 1201 equations, 2510 variables
# MODEL PATH: model_4x300.onnx
# Found a counterexample within the 1% ε-ball that changes the classification.
# 	x45: [  0.0173,   0.0176]
# 	x46: [  0.0001,   0.0001] [FIXED]
# 	x47: [  0.2347,   0.2395]
# 	x48: [  0.0266,   0.0272]
# 	x49: [  0.1241,   0.1266]
# 	x50: [  0.0357,   0.0365]
# 	x51: [  0.0404,   0.0412]
# 	x52: [  0.0241,   0.0246]
# 	x53: [  0.7472,   0.7623]
# 	x54: [  0.1081,   0.1103]
# 	x55: [  0.0047,   0.0048]
# 	x56: [  0.0085,   0.0086]
# 	x57: [  0.0275,   0.0281]
# 	x58: [  0.0941,   0.0960]
# 	x59: [  0.0045,   0.0046]
# 	x60: [  0.0348,   0.0356]
# 	x61: [  0.0489,   0.0498]
# 	x62: [  0.0032,   0.0032]
# 	x63: [  0.8986,   0.9167]
# 	x64: [  0.1489,   0.1519]
# 	x65: [  0.8411,   0.8581]
# 	x66: [  0.0009,   0.0009]
# 	x67: [  0.0049,   0.0050]
# 	x68: [  0.0025,   0.0026]
# 	x69: [  0.0003,   0.0003] [FIXED]
# 	x70: [  0.0032,   0.0032]
# 	x71: [  0.0003,   0.0003] [FIXED]
# 	x72: [  0.0005,   0.0005]
# 	x73: [  0.0011,   0.0012]
# 	x74: [  0.0038,   0.0039]
# 	x75: [  0.0015,   0.0015]
# 	x76: [  0.0056,   0.0057]
# 	x77: [  0.0010,   0.0010]
# 	x78: [  0.0004,   0.0004] [FIXED]
# 	x79: [  0.0005,   0.0005]
# 	x80: [  0.0000,   0.0000] [FIXED]
# 	x81: [  0.0001,   0.0001] [FIXED]
# 	x82: [  0.0008,   0.0008]
# 	x83: [  0.0004,   0.0004] [FIXED]
# 	x84: [  0.0051,   0.0052]
# 	x85: [  0.0023,   0.0023]
# 	x86: [  0.0006,   0.0006]
# 	x87: [  0.0032,   0.0032]
# 	x88: [  0.0013,   0.0013]
# 	x89: [  0.0030,   0.0031]
# 	x90: [  0.0003,   0.0003] [FIXED]
# 	x91: [  0.0042,   0.0043]
# 	x92: [  0.0003,   0.0003] [FIXED]
# 	x93: [  0.0000,   0.0000] [FIXED]
# 	x94: [  0.0003,   0.0003] [FIXED]
# 	x95: [  0.0077,   0.0079]
# 	x96: [  0.0015,   0.0015]
# 	x97: [  0.0005,   0.0005]
# 	x98: [  0.0015,   0.0015]
# 	x99: [  0.0004,   0.0004] [FIXED]
# 	x100: [  0.0020,   0.0021]
# 	x101: [  0.0025,   0.0026]
# 	x102: [  0.0004,   0.0004] [FIXED]
# 	x103: [  0.0003,   0.0003] [FIXED]
# 	x104: [  0.9054,   0.9237]
# 	x105: [  0.0006,   0.0006]
# 	x106: [  0.0008,   0.0008]
# 	x107: [  0.0184,   0.0188]
#
# Branching heuristics set to PseudoImpact
#
# Engine::solve: Initial statistics
#
# 19:42:04 Statistics update:
# 	--- Time Statistics ---
# 	Total time elapsed: 2340 milli (00:00:02)
# 		Main loop: 0 milli (00:00:00)
# 		Preprocessing time: 2064 milli (00:00:02)
# 		Unknown: 275 milli (00:00:00)
# 	Breakdown for main loop:
# 		[0.00%] Simplex steps: 0 milli
# 		[0.00%] Explicit-basis bound tightening: 0 milli
# 		[0.00%] Constraint-matrix bound tightening: 0 milli
# 		[0.00%] Degradation checking: 0 milli
# 		[0.00%] Precision restoration: 0 milli
# 		[0.00%] Statistics handling: 0 milli
# 		[0.00%] Constraint-fixing steps: 0 milli
# 		[0.00%] Valid case splits: 0 milli. Average per split: 0.00 milli
# 		[0.00%] Applying stored bound-tightening: 0 milli
# 		[0.00%] SMT core: 0 milli
# 		[0.00%] Symbolic Bound Tightening: 615 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] Unaccounted for: 0 milli
# 	--- Preprocessor Statistics ---
# 	Number of preprocessor bound-tightening loop iterations: 7
# 	Number of eliminated variables: 851
# 	Number of constraints removed due to variable elimination: 833
# 	Number of equations removed due to variable elimination: 0
# 	--- Engine Statistics ---
# 	Number of main loop iterations: 1
# 		0 iterations were simplex steps. Total time: 0 milli. Average: 0.00 milli.
# 		0 iterations were constraint-fixing steps. Total time: 0 milli. Average: 0.00 milli
# 	Number of active piecewise-linear constraints: 367 / 367
# 		Constraints disabled by valid splits: 0. By SMT-originated splits: 0
# 	Last reported degradation: 0.0000000000. Max degradation so far: 0.0000000000. Restorations so far: 0
# 	Number of simplex pivots we attempted to skip because of instability: 0.
# 	Unstable pivots performed anyway: 0
# 	--- Tableau Statistics ---
# 	Total number of pivots performed: 0
# 		Real pivots: 0. Degenerate: 0 (0.00%)
# 		Degenerate pivots by request (e.g., to fix a PL constraint): 0 (0.00%)
# 		Average time per pivot: 0.00 milli
# 	Total number of fake pivots performed: 0
# 	Total number of rows added: 0. Number of merged columns: 0
# 	Current tableau dimensions: M = 2401, N = 5278
# 	--- SMT Core Statistics ---
# 	Total depth is 0. Total visited states: 1. Number of splits: 0. Number of pops: 0
# 	Max stack depth: 0
# 	--- Bound Tightening Statistics ---
# 	Number of tightened bounds: 0.
# 		Number of rows examined by row tightener: 0. Consequent tightenings: 0
# 		Number of explicit basis matrices examined by row tightener: 0. Consequent tightenings: 0
# 		Number of bound tightening rounds on the entire constraint matrix: 0. Consequent tightenings: 0
# 		Number of bound notifications sent to PL constraints: 2202. Tightenings proposed: 0
# 	--- Basis Factorization statistics ---
# 	Number of basis refactorizations: 2
# 	--- Projected Steepest Edge Statistics ---
# 	Number of iterations: 0.
# 	Number of resets to reference space: 1. Avg. iterations per reset: 0
# 	--- SBT ---
# 	Number of tightened bounds: 2456
# 	--- SoI-based local search ---
# 	Number of proposed phase pattern update: 0. Number of accepted update: 0 [0.00%]
# 	Total time (% of local search time) updating SoI phase pattern : 0 milli [0.00%]
# 	Total time obtaining current assignment: 0 milli [0.00%]
# 	Total time getting SoI phase pattern : 0 milli [0.00%]
# 	--- Context dependent statistics ---
# 	Number of pushes / pops: 0 / 0
# 		[0.00%] Pre-Push hook: 0 milli
# 		[0.00%] Push : 0 milli
# 		[0.00%] Post-Pop hook: 0 milli
# 		[0.00%] Pop : 0 milli
# 		[0.00%] Total context-switching time: 0 milli
# 	--- Proof Certificate ---
# 	Number of certified leaves: 0
# 	Number of leaves to delegate: 0
#
# ---
# Before declaring sat, recomputing...
#
# Engine::solve: sat assignment found
#
# 19:42:20 Statistics update:
# 	--- Time Statistics ---
# 	Total time elapsed: 17682 milli (00:00:17)
# 		Main loop: 15340 milli (00:00:15)
# 		Preprocessing time: 2064 milli (00:00:02)
# 		Unknown: 277 milli (00:00:00)
# 	Breakdown for main loop:
# 		[22.66%] Simplex steps: 3476 milli
# 		[75.01%] Explicit-basis bound tightening: 11506 milli
# 		[0.00%] Constraint-matrix bound tightening: 0 milli
# 		[0.39%] Degradation checking: 60 milli
# 		[0.00%] Precision restoration: 0 milli
# 		[0.02%] Statistics handling: 3 milli
# 		[0.00%] Constraint-fixing steps: 0 milli
# 		[0.01%] Valid case splits: 1 milli. Average per split: 0.00 milli
# 		[0.00%] Applying stored bound-tightening: 0 milli
# 		[0.00%] SMT core: 0 milli
# 		[5.83%] Symbolic Bound Tightening: 894 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[120247465858580.25%] Unaccounted for: 0 milli
# 	--- Preprocessor Statistics ---
# 	Number of preprocessor bound-tightening loop iterations: 7
# 	Number of eliminated variables: 851
# 	Number of constraints removed due to variable elimination: 833
# 	Number of equations removed due to variable elimination: 0
# 	--- Engine Statistics ---
# 	Number of main loop iterations: 1113
# 		1110 iterations were simplex steps. Total time: 3476 milli. Average: 3.13 milli.
# 		0 iterations were constraint-fixing steps. Total time: 0 milli. Average: 0.00 milli
# 	Number of active piecewise-linear constraints: 0 / 367
# 		Constraints disabled by valid splits: 367. By SMT-originated splits: 0
# 	Last reported degradation: 0.0000000193. Max degradation so far: 0.0000000193. Restorations so far: 0
# 	Number of simplex pivots we attempted to skip because of instability: 0.
# 	Unstable pivots performed anyway: 0
# 	--- Tableau Statistics ---
# 	Total number of pivots performed: 923
# 		Real pivots: 899. Degenerate: 24 (2.60%)
# 		Degenerate pivots by request (e.g., to fix a PL constraint): 0 (0.00%)
# 		Average time per pivot: 1.75 milli
# 	Total number of fake pivots performed: 187
# 	Total number of rows added: 0. Number of merged columns: 0
# 	Current tableau dimensions: M = 2401, N = 5278
# 	--- SMT Core Statistics ---
# 	Total depth is 0. Total visited states: 1. Number of splits: 0. Number of pops: 0
# 	Max stack depth: 0
# 	--- Bound Tightening Statistics ---
# 	Number of tightened bounds: 0.
# 		Number of rows examined by row tightener: 923. Consequent tightenings: 1
# 		Number of explicit basis matrices examined by row tightener: 12. Consequent tightenings: 1291
# 		Number of bound tightening rounds on the entire constraint matrix: 0. Consequent tightenings: 0
# 		Number of bound notifications sent to PL constraints: 4621. Tightenings proposed: 0
# 	--- Basis Factorization statistics ---
# 	Number of basis refactorizations: 10
# 	--- Projected Steepest Edge Statistics ---
# 	Number of iterations: 1110.
# 	Number of resets to reference space: 1. Avg. iterations per reset: 1110
# 	--- SBT ---
# 	Number of tightened bounds: 2456
# 	--- SoI-based local search ---
# 	Number of proposed phase pattern update: 0. Number of accepted update: 0 [0.00%]
# 	Total time (% of local search time) updating SoI phase pattern : 0 milli [0.00%]
# 	Total time obtaining current assignment: 0 milli [0.00%]
# 	Total time getting SoI phase pattern : 0 milli [0.00%]
# 	--- Context dependent statistics ---
# 	Number of pushes / pops: 0 / 0
# 		[0.00%] Pre-Push hook: 0 milli
# 		[0.00%] Push : 0 milli
# 		[0.00%] Post-Pop hook: 0 milli
# 		[0.00%] Pop : 0 milli
# 		[0.00%] Total context-switching time: 0 milli
# 	--- Proof Certificate ---
# 	Number of certified leaves: 0
# 	Number of leaves to delegate: 0
# Engine::processInputQuery: Input query (before preprocessing): 601 equations, 1310 variables
# MODEL PATH: model_6x100.onnx
# Found a counterexample within the 1% ε-ball that changes the classification.
# ...
# 	Max stack depth: 0
# 	--- Bound Tightening Statistics ---
# 	Number of tightened bounds: 0.
# 		Number of rows examined by row tightener: 2161. Consequent tightenings: 20
# 		Number of explicit basis matrices examined by row tightener: 22. Consequent tightenings: 3107
# 		Number of bound tightening rounds on the entire constraint matrix: 0. Consequent tightenings: 0
# 		Number of bound notifications sent to PL constraints: 12105. Tightenings proposed: 0
# 	--- Basis Factorization statistics ---
# 	Number of basis refactorizations: 22
# 	--- Projected Steepest Edge Statistics ---
# 	Number of iterations: 2382.
# 	Number of resets to reference space: 3. Avg. iterations per reset: 794
# 	--- SBT ---
# 	Number of tightened bounds: 4157
# 	--- SoI-based local search ---
# 	Number of proposed phase pattern update: 0. Number of accepted update: 1 [0.00%]
# 	Total time (% of local search time) updating SoI phase pattern : 2215 milli [17.90%]
# 	Total time obtaining current assignment: 1641 milli [13.26%]
# 	Total time getting SoI phase pattern : 6 milli [0.00%]
# 	--- Context dependent statistics ---
# 	Number of pushes / pops: 0 / 0
# 		[0.00%] Pre-Push hook: 0 milli
# 		[0.00%] Push : 0 milli
# 		[0.00%] Post-Pop hook: 0 milli
# 		[0.00%] Pop : 0 milli
# 		[0.00%] Total context-switching time: 0 milli
# 	--- Proof Certificate ---
# 	Number of certified leaves: 0
# 	Number of leaves to delegate: 0
# Engine::processInputQuery: Input query (before preprocessing): 2401 equations, 4910 variables
# Engine::processInputQuery: Input query (after preprocessing): 4801 equations, 6482 variables
#
# Input bounds:
# 	x0: [ 43.8073,  44.6923]
# 	x1: [186124.9500, 189885.0500]
# 	x2: [ 11.4955,  11.7278]
# 	x3: [3966.0810, 4046.2039]
# 	x4: [193.0515, 196.9515]
# 	x5: [ 45.0183,  45.9278]
# 	x6: [  0.0468,   0.0478]
# 	x7: [  0.0779,   0.0795]
# 	x8: [  0.0000,   0.0000] [FIXED]
# 	x9: [  0.6266,   0.6393]
# 	x10: [  0.0785,   0.0801]
# 	x11: [  0.0914,   0.0933]
# 	x12: [  0.0446,   0.0455]
# 	x13: [  0.0000,   0.0000] [FIXED]
# 	x14: [  0.0241,   0.0246]
# 	x15: [  0.0078,   0.0080]
# 	x16: [  0.0076,   0.0077]
# 	x17: [  0.0042,   0.0043]
# 	x18: [  0.0008,   0.0008]
# 	x19: [  0.0020,   0.0021]
# 	x20: [  0.0051,   0.0052]
# 	x21: [  0.0034,   0.0035]
# 	x22: [  0.0335,   0.0341]
# 	x23: [  0.0456,   0.0465]
# 	x24: [  0.2804,   0.2861]
# 	x25: [  0.0386,   0.0394]
# 	x26: [  0.2115,   0.2158]
# 	x27: [  0.1211,   0.1235]
# 	x28: [  0.0000,   0.0000] [FIXED]
# 	x29: [  0.0534,   0.0545]
# 	x30: [  0.1751,   0.1787]
# 	x31: [  0.0585,   0.0596]
# 	x32: [  0.0013,   0.0013]
# 	x33: [  0.8449,   0.8620]
# 	x34: [  0.0043,   0.0044]
# 	x35: [  0.0620,   0.0632]
# 	x36: [  0.0083,   0.0085]
# 	x37: [  0.0107,   0.0109]
# 	x38: [  0.0640,   0.0653]
# 	x39: [  0.0001,   0.0001] [FIXED]
# 	x40: [  0.1173,   0.1197]
# 	x41: [  0.2485,   0.2535]
# 	x42: [  0.0145,   0.0148]
# 	x43: [  0.0109,   0.0111]
# 	x44: [  0.0316,   0.0322]
# 	x45: [  0.0173,   0.0176]
# 	x46: [  0.0001,   0.0001] [FIXED]
# 	x47: [  0.2347,   0.2395]
# 	x48: [  0.0266,   0.0272]
# 	x49: [  0.1241,   0.1266]
# 	x50: [  0.0357,   0.0365]
# 	x51: [  0.0404,   0.0412]
# 	x52: [  0.0241,   0.0246]
# 	x53: [  0.7472,   0.7623]
# 	x54: [  0.1081,   0.1103]
# 	x55: [  0.0047,   0.0048]
# 	x56: [  0.0085,   0.0086]
# 	x57: [  0.0275,   0.0281]
# 	x58: [  0.0941,   0.0960]
# 	x59: [  0.0045,   0.0046]
# 	x60: [  0.0348,   0.0356]
# 	x61: [  0.0489,   0.0498]
# 	x62: [  0.0032,   0.0032]
# 	x63: [  0.8986,   0.9167]
# 	x64: [  0.1489,   0.1519]
# 	x65: [  0.8411,   0.8581]
# 	x66: [  0.0009,   0.0009]
# 	x67: [  0.0049,   0.0050]
# 	x68: [  0.0025,   0.0026]
# 	x69: [  0.0003,   0.0003] [FIXED]
# 	x70: [  0.0032,   0.0032]
# 	x71: [  0.0003,   0.0003] [FIXED]
# 	x72: [  0.0005,   0.0005]
# 	x73: [  0.0011,   0.0012]
# 	x74: [  0.0038,   0.0039]
# 	x75: [  0.0015,   0.0015]
# 	x76: [  0.0056,   0.0057]
# 	x77: [  0.0010,   0.0010]
# 	x78: [  0.0004,   0.0004] [FIXED]
# 	x79: [  0.0005,   0.0005]
# 	x80: [  0.0000,   0.0000] [FIXED]
# 	x81: [  0.0001,   0.0001] [FIXED]
# 	x82: [  0.0008,   0.0008]
# 	x83: [  0.0004,   0.0004] [FIXED]
# 	x84: [  0.0051,   0.0052]
# 	x85: [  0.0023,   0.0023]
# 	x86: [  0.0006,   0.0006]
# 	x87: [  0.0032,   0.0032]
# 	x88: [  0.0013,   0.0013]
# 	x89: [  0.0030,   0.0031]
# 	x90: [  0.0003,   0.0003] [FIXED]
# 	x91: [  0.0042,   0.0043]
# 	x92: [  0.0003,   0.0003] [FIXED]
# 	x93: [  0.0000,   0.0000] [FIXED]
# 	x94: [  0.0003,   0.0003] [FIXED]
# 	x95: [  0.0077,   0.0079]
# 	x96: [  0.0015,   0.0015]
# 	x97: [  0.0005,   0.0005]
# 	x98: [  0.0015,   0.0015]
# 	x99: [  0.0004,   0.0004] [FIXED]
# 	x100: [  0.0020,   0.0021]
# 	x101: [  0.0025,   0.0026]
# 	x102: [  0.0004,   0.0004] [FIXED]
# 	x103: [  0.0003,   0.0003] [FIXED]
# 	x104: [  0.9054,   0.9237]
# 	x105: [  0.0006,   0.0006]
# 	x106: [  0.0008,   0.0008]
# 	x107: [  0.0184,   0.0188]
#
# Branching heuristics set to PseudoImpact
#
# Engine::solve: Initial statistics
#
# 19:45:43 Statistics update:
# 	--- Time Statistics ---
# 	Total time elapsed: 6456 milli (00:00:06)
# 		Main loop: 0 milli (00:00:00)
# 		Preprocessing time: 5798 milli (00:00:05)
# 		Unknown: 658 milli (00:00:00)
# 	Breakdown for main loop:
# 		[0.00%] Simplex steps: 0 milli
# 		[0.00%] Explicit-basis bound tightening: 0 milli
# 		[0.00%] Constraint-matrix bound tightening: 0 milli
# 		[0.00%] Degradation checking: 0 milli
# 		[0.00%] Precision restoration: 0 milli
# 		[0.00%] Statistics handling: 0 milli
# 		[0.00%] Constraint-fixing steps: 0 milli
# 		[0.00%] Valid case splits: 0 milli. Average per split: 0.00 milli
# 		[0.00%] Applying stored bound-tightening: 0 milli
# 		[0.00%] SMT core: 0 milli
# 		[0.00%] Symbolic Bound Tightening: 1672 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[0.00%] Unaccounted for: 0 milli
# 	--- Preprocessor Statistics ---
# 	Number of preprocessor bound-tightening loop iterations: 13
# 	Number of eliminated variables: 846
# 	Number of constraints removed due to variable elimination: 828
# 	Number of equations removed due to variable elimination: 0
# 	--- Engine Statistics ---
# 	Number of main loop iterations: 1
# 		0 iterations were simplex steps. Total time: 0 milli. Average: 0.00 milli.
# 		0 iterations were constraint-fixing steps. Total time: 0 milli. Average: 0.00 milli
# 	Number of active piecewise-linear constraints: 1572 / 1572
# 		Constraints disabled by valid splits: 0. By SMT-originated splits: 0
# 	Last reported degradation: 0.0000000000. Max degradation so far: 0.0000000000. Restorations so far: 0
# 	Number of simplex pivots we attempted to skip because of instability: 0.
# 	Unstable pivots performed anyway: 0
# 	--- Tableau Statistics ---
# 	Total number of pivots performed: 0
# 		Real pivots: 0. Degenerate: 0 (0.00%)
# 		Degenerate pivots by request (e.g., to fix a PL constraint): 0 (0.00%)
# 		Average time per pivot: 0.00 milli
# 	Total number of fake pivots performed: 0
# 	Total number of rows added: 0. Number of merged columns: 0
# 	Current tableau dimensions: M = 4801, N = 11283
# 	--- SMT Core Statistics ---
# 	Total depth is 0. Total visited states: 1. Number of splits: 0. Number of pops: 0
# 	Max stack depth: 0
# 	--- Bound Tightening Statistics ---
# 	Number of tightened bounds: 0.
# 		Number of rows examined by row tightener: 0. Consequent tightenings: 0
# 		Number of explicit basis matrices examined by row tightener: 0. Consequent tightenings: 0
# 		Number of bound tightening rounds on the entire constraint matrix: 0. Consequent tightenings: 0
# 		Number of bound notifications sent to PL constraints: 9432. Tightenings proposed: 0
# 	--- Basis Factorization statistics ---
# 	Number of basis refactorizations: 2
# 	--- Projected Steepest Edge Statistics ---
# 	Number of iterations: 0.
# 	Number of resets to reference space: 1. Avg. iterations per reset: 0
# 	--- SBT ---
# 	Number of tightened bounds: 6314
# 	--- SoI-based local search ---
# 	Number of proposed phase pattern update: 0. Number of accepted update: 0 [0.00%]
# 	Total time (% of local search time) updating SoI phase pattern : 0 milli [0.00%]
# 	Total time obtaining current assignment: 0 milli [0.00%]
# 	Total time getting SoI phase pattern : 0 milli [0.00%]
# 	--- Context dependent statistics ---
# 	Number of pushes / pops: 0 / 0
# 		[0.00%] Pre-Push hook: 0 milli
# 		[0.00%] Push : 0 milli
# 		[0.00%] Post-Pop hook: 0 milli
# 		[0.00%] Pop : 0 milli
# 		[0.00%] Total context-switching time: 0 milli
# 	--- Proof Certificate ---
# 	Number of certified leaves: 0
# 	Number of leaves to delegate: 0
#
# ---
#
# Engine::solve: sat assignment found
#
# 19:49:48 Statistics update:
# 	--- Time Statistics ---
# 	Total time elapsed: 251287 milli (00:04:11)
# 		Main loop: 244823 milli (00:04:04)
# 		Preprocessing time: 5798 milli (00:00:05)
# 		Unknown: 665 milli (00:00:00)
# 	Breakdown for main loop:
# 		[13.38%] Simplex steps: 32767 milli
# 		[85.62%] Explicit-basis bound tightening: 209618 milli
# 		[0.00%] Constraint-matrix bound tightening: 0 milli
# 		[0.36%] Degradation checking: 872 milli
# 		[0.00%] Precision restoration: 0 milli
# 		[0.04%] Statistics handling: 88 milli
# 		[0.00%] Constraint-fixing steps: 0 milli
# 		[0.00%] Valid case splits: 10 milli. Average per split: 0.00 milli
# 		[0.00%] Applying stored bound-tightening: 0 milli
# 		[0.00%] SMT core: 0 milli
# 		[1.24%] Symbolic Bound Tightening: 3029 milli
# 		[0.01%] SoI-based local search: 30 milli
# 		[0.00%] SoI-based local search: 0 milli
# 		[7534708223804.33%] Unaccounted for: 0 milli
# 	--- Preprocessor Statistics ---
# 	Number of preprocessor bound-tightening loop iterations: 13
# 	Number of eliminated variables: 846
# 	Number of constraints removed due to variable elimination: 828
# 	Number of equations removed due to variable elimination: 0
# 	--- Engine Statistics ---
# 	Number of main loop iterations: 3296
# 		3294 iterations were simplex steps. Total time: 32767 milli. Average: 9.95 milli.
# 		0 iterations were constraint-fixing steps. Total time: 0 milli. Average: 0.00 milli
# 	Number of active piecewise-linear constraints: 2 / 1572
# 		Constraints disabled by valid splits: 1570. By SMT-originated splits: 0
# 	Last reported degradation: 0.0000000510. Max degradation so far: 0.0000000512. Restorations so far: 0
# 	Number of simplex pivots we attempted to skip because of instability: 0.
# 	Unstable pivots performed anyway: 0
# 	--- Tableau Statistics ---
# 	Total number of pivots performed: 3082
# 		Real pivots: 2891. Degenerate: 191 (6.20%)
# 		Degenerate pivots by request (e.g., to fix a PL constraint): 0 (0.00%)
# 		Average time per pivot: 5.28 milli
# 	Total number of fake pivots performed: 210
# 	Total number of rows added: 0. Number of merged columns: 0
# 	Current tableau dimensions: M = 4801, N = 11283
# 	--- SMT Core Statistics ---
# 	Total depth is 0. Total visited states: 1. Number of splits: 0. Number of pops: 0
# 	Max stack depth: 0
# 	--- Bound Tightening Statistics ---
# 	Number of tightened bounds: 0.
# 		Number of rows examined by row tightener: 3082. Consequent tightenings: 1
# 		Number of explicit basis matrices examined by row tightener: 31. Consequent tightenings: 4581
# 		Number of bound tightening rounds on the entire constraint matrix: 0. Consequent tightenings: 0
# 		Number of bound notifications sent to PL constraints: 20040. Tightenings proposed: 0
# 	--- Basis Factorization statistics ---
# 	Number of basis refactorizations: 30
# 	--- Projected Steepest Edge Statistics ---
# 	Number of iterations: 3292.
# 	Number of resets to reference space: 4. Avg. iterations per reset: 823
# 	--- SBT ---
# 	Number of tightened bounds: 6314
# 	--- SoI-based local search ---
# 	Number of proposed phase pattern update: 0. Number of accepted update: 1 [0.00%]
# 	Total time (% of local search time) updating SoI phase pattern : 10976 milli [36.20%]
# 	Total time obtaining current assignment: 2406 milli [7.93%]
# 	Total time getting SoI phase pattern : 3 milli [0.00%]
# 	--- Context dependent statistics ---
# 	Number of pushes / pops: 0 / 0
# 		[0.00%] Pre-Push hook: 0 milli
# 		[0.00%] Push : 0 milli
# 		[0.00%] Post-Pop hook: 0 milli
# 		[0.00%] Pop : 0 milli
# 		[0.00%] Total context-switching time: 0 milli
# 	--- Proof Certificate ---
# 	Number of certified leaves: 0
# 	Number of leaves to delegate: 0
# MODEL PATH: model_8x300.onnx
# Found a counterexample within the 1% ε-ball that changes the classification.
# Counterexample: {0: 44.69233898737406, 1: 186124.95, 2: 11.727773243208775, 3: 4046.2038808825405, 4: 196.95154572120904, 5: 45.92775666369085, 6: 0.04684223951026655, 7: 0.07790205330952685, 8: 0.0, 9: 0.6266254304297921, 10: 0.07853335033796709, 11: 0.09325851294477745, 12: 0.04546996556561663, 13: 0.0, 14: 0.02411554648641755, 15: 0.0078280831526591, 16: 0.007575564341282999, 17: 0.004166560387705649, 18: 0.0007575564341283, 19: 0.0020201504910088, 20: 0.005050376227521999, 21: 0.00340900395357735, 22: 0.03345874250733325, 23: 0.04650044637163627, 24: 0.28608723377120265, 25: 0.03941589083025124, 26: 0.21148450452748374, 27: 0.12108277005483994, 28: 0.0, 29: 0.05340772860604515, 30: 0.17865960974365513, 31: 0.05845810483356715, 32: 0.0012881010075245505, 33: 0.8619971942354292, 34: 0.0042928197933937, 35: 0.06199336819283255, 36: 0.008333120775411299, 37: 0.01073204948348425, 38: 0.06401351868384135, 39: 0.00012625940568805, 40: 0.11729498788419845, 41: 0.2484785103940824, 42: 0.014519831654125749